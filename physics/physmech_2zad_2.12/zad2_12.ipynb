# %%
import numpy as np
from matplotlib import pyplot as plt
from types import SimpleNamespace
pi = np.pi

# %%
const = SimpleNamespace()
const.hbar = 0.659 * 1e-15
const.m_e = 0.510 * 1e6
const.g_A = 1
const.K_B = 1.38067 * 1e-16

# %%
def sigma(x):

# %%
S_T = np.loadtxt('S(T).txt').T
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(10)
plt.plot(S_T[0], S_T[1])
plt.grid()
plt.xlabel('T, K')
plt.ylabel('S(T)')
plt.show()
fig.savefig('S(T).pdf')

# %%
sigma_x = np.loadtxt('sigma(x).txt').T
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(10)
plt.plot(sigma_x[0], sigma_x[1])
plt.grid()
plt.xlabel('x')
plt.ylabel(r'$\sigma(x)$')
plt.show()
fig.savefig('sigma(x).pdf')

# %% [markdown]
# $\rightleftarrows$
